# %% [markdown]
# https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/data
#
# - Our Dataset

# %% [markdown]
# https://www.kaggle.com/code/tentotheminus9/what-causes-heart-disease-explaining-the-model?scriptVersionId=11135525&cellId=10
#
# - Has deeper explianations

# %% [markdown]
# It's a clean, easy to understand set of data. However, the meaning of some of
#
# 1.   List item
# 2.   List item
#
# the column headers are not obvious. Here's what they mean,
#
# age: The person's age in years
#
# sex: The person's sex (1 = male, 0 = female)
#
# cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# chol: The person's cholesterol measurement in mg/dl
# fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# thalach: The person's maximum heart rate achieved
# exang: Exercise induced angina (1 = yes; 0 = no)
#
# oldpeak: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
#
# slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# ca: The number of major vessels (0-3)
#
# thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# target: Heart disease (0 = no, 1 = yes)

# %% [markdown]
# 1. Number of Records:
#  The dataset contains 303 records (rows), which represent individual patient data.
# 2. Number and Types of Features:
# The dataset has a total of 14 columns (features), including the target class.
# These features include a mix of numeric and categorical variables, such as:
# Numerical Features:
# age: Age of the patient.
# trestbps: Resting blood pressure (mm Hg).
# chol: Serum cholesterol in mg/dl.
# thalach: Maximum heart rate achieved.
# oldpeak: ST depression induced by exercise relative to rest.
# Categorical Features:
# sex: Gender (1 = male, 0 = female).
# cp: Chest pain type (0 to 3).
# fbs: Fasting blood sugar > 120 mg/dl (1 = true, 0 = false).
# restecg: Resting electrocardiographic results (0, 1, 2).
# exang: Exercise-induced angina (1 = yes, 0 = no).
# slope: The slope of the peak exercise ST segment (0, 1, 2).
# ca: Number of major vessels colored by fluoroscopy (0 to 3).
# thal: Thalassemia (0 = normal, 1 = fixed defect, 2 = reversible defect).
# 3. Detected Anomalies:
# Some common anomalies that has been detected in this dataset:
# Missing Values
# Inconsistent Categorical Data: For example, values in the ca (number of major vessels) or thal (thalassemia) columns  need closer inspection for consistency.
# 4. Which Feature is the Target Class:
# target: This is a binary variable where:
# 1 = The patient has heart disease.
# 0 = The patient does not have heart disease.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('heart.csv')
data.shape
# Out:
# (303, 14)

# %% [markdown]
# #Renaming the cols

# %%
# Assuming 'df' is your DataFrame
data = data.rename(columns={
    'age': 'Age',
    'sex': 'Sex',
    'cp': 'Chest_Pain',
    'trtbps': 'Rest_BP',
    'chol': 'Cholesterol',
    'fbs': 'Fasting_BS',
    'restecg': 'Rest_ECG',
    'thalachh': 'Max_HR',
    'exng': 'Ex_Angina',
    'oldpeak': 'ST_Depression',
    'slp': 'Slope',
    'caa': 'Vessel_Count',
    'thall': 'Max_HR_PostEx',  # Max Heart Rate for thall
    'output': 'Heart_Disease'
})


data = pd.DataFrame(data)
data.head()
# Out:
#    Age  Sex  Chest_Pain  Rest_BP  Cholesterol  Fasting_BS  Rest_ECG  Max_HR  \
# 0   63    1           3      145          233           1         0     150
# 1   37    1           2      130          250           0         1     187
# 2   41    0           1      130          204           0         0     172
# 3   56    1           1      120          236           0         1     178
# 4   57    0           0      120          354           0         1     163
#
#    Ex_Angina  ST_Depression  Slope  Vessel_Count  Max_HR_PostEx  Heart_Disease
# 0          0            2.3      0             0              1              1
# 1          0            3.5      0             0              2              1
# 2          0            1.4      2             0              2              1
# 3          0            0.8      2             0              2              1
# 4          1            0.6      2             0              2              1

# %% [markdown]
# #Checking nulls

# %% [markdown]
# #Stats on each col

# %%
X = data.drop(['Heart_Disease'], axis=1)

y = data['Heart_Disease'];

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# check data types in X_train

X_train.dtypes
# Out:
# Age                int64
# Sex                int64
# Chest_Pain         int64
# Rest_BP            int64
# Cholesterol        int64
# Fasting_BS         int64
# Rest_ECG           int64
# Max_HR             int64
# Ex_Angina          int64
# ST_Depression    float64
# Slope              int64
# Vessel_Count       int64
# Max_HR_PostEx      int64
# dtype: object

# %%
cols = X_train.columns

# %%
from sklearn.preprocessing import StandardScaler



scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])

# %%
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
# import KNeighbors ClaSSifier from sklearn
from sklearn.neighbors import KNeighborsClassifier

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression


# instantiate the models
knn = KNeighborsClassifier(n_neighbors=9)
nb = GaussianNB()
tree = DecisionTreeClassifier()



# fit the model to the training set
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = knn.predict(X_test)

y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model(KNN) accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# print('Model(Decision Tree) accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred_tree)))
print('Model(NB) accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred_nb)))
# Out:
# Model(KNN) accuracy score: 0.8525
# Model(NB) accuracy score: 0.8525

# %%
# print the scores on training and test set
print('KNN MODEL')
print('Training set score: {:.4f}'.format(knn.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(knn.score(X_test, y_test)))
print('---------------------------------------')

# print('Decision Tree Model')
# print('Training set score: {:.4f}'.format(tree.score(X_train, y_train)))
# print('Test set score: {:.4f}'.format(tree.score(X_test, y_test)))
# print('---------------------------------------')

print('Naive Bayes Model')
print('Training set score: {:.4f}'.format(nb.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(nb.score(X_test, y_test)))
print('---------------------------------------')
# Out:
# KNN MODEL
# Training set score: 0.8554
# Test set score: 0.8525
# ---------------------------------------
# Naive Bayes Model
# Training set score: 0.8347
# Test set score: 0.8525
# ---------------------------------------

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt

# Function to print metrics and plot ROC
def evaluate_model(model, X_train, y_train, X_test, y_test, model_name):
    print(f"{model_name.upper()} MODEL")

    # Scores
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"Training set score: {train_score:.4f}")
    print(f"Test set score: {test_score:.4f}")

    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    print("Metrics:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall (TPR): {recall:.4f}")
    print(f"  F1 Score: {f1:.4f}")

    # ROC Curve
    if y_pred_proba is not None:
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        plt.figure()
        plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve - {model_name}")
        plt.legend()
        plt.show()

    print("---------------------------------------\n")

# Evaluate models
evaluate_model(knn, X_train, y_train, X_test, y_test, "KNN")
# evaluate_model(tree, X_train, y_train, X_test, y_test, "Decision Tree")
evaluate_model(nb, X_train, y_train, X_test, y_test, "Naive Bayes")
# Out:
# KNN MODEL
# Training set score: 0.8554
# Test set score: 0.8525
# Metrics:
#   Accuracy: 0.8525
#   Precision: 0.8378
#   Recall (TPR): 0.9118
#   F1 Score: 0.8732
# ---------------------------------------
#
# NAIVE BAYES MODEL
# Training set score: 0.8347
# Test set score: 0.8525
# Metrics:
#   Accuracy: 0.8525
#   Precision: 0.8378
#   Recall (TPR): 0.9118
#   F1 Score: 0.8732
# ---------------------------------------

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from itertools import combinations
import random
from itertools import combinations


target = "Heart_Disease"
features = [col for col in data.columns if col != target]


# Function to evaluate models
def evaluate_model(model, X_train, y_train, X_test, y_test, model_name):
    print(f"{model_name.upper()} MODEL")

    # Scores
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"Training set score: {train_score:.4f}")
    print(f"Test set score: {test_score:.4f}")

    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    print("Metrics:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall (TPR): {recall:.4f}")
    print(f"  F1 Score: {f1:.4f}")

    # ROC Curve
    if y_pred_proba is not None:
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        plt.figure()
        plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
        plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve - {model_name}")
        plt.legend()
        plt.show()

    print("---------------------------------------\n")

# Evaluate on all features
print("\n--- Evaluating with All Features ---")
X = data[features]
y = data[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train and evaluate models
knn = KNeighborsClassifier(n_neighbors=9)
nb = GaussianNB()

knn.fit(X_train, y_train)
nb.fit(X_train, y_train)

evaluate_model(knn, X_train, y_train, X_test, y_test, "KNN (All Features)")
evaluate_model(nb, X_train, y_train, X_test, y_test, "Naive Bayes (All Features)")

# Generate feature subsets
subset_sizes = [3, 5]  # Choose smaller subset sizes
feature_combos = [combo for size in subset_sizes for combo in combinations(features, size)]

# Randomly sample a limited number of combinations
random.seed(42)
selected_combos = random.sample(feature_combos, 5)  # Pick 5 random combinations

# Iterate over the selected subsets
for combo in selected_combos:
    print(f"\n--- Using Features: {combo} ---")
    selected_features = list(combo)

    # Split data
    X = data[selected_features]
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Scale data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Train and evaluate models
    knn = KNeighborsClassifier(n_neighbors=9)
    nb = GaussianNB()

    knn.fit(X_train, y_train)
    nb.fit(X_train, y_train)

    evaluate_model(knn, X_train, y_train, X_test, y_test, "KNN")
    evaluate_model(nb, X_train, y_train, X_test, y_test, "Naive Bayes")
# Out:
# --- Evaluating with All Features ---
# KNN (ALL FEATURES) MODEL
# Training set score: 0.8388
# Test set score: 0.8525
# Metrics:
#   Accuracy: 0.8525
#   Precision: 0.8378
#   Recall (TPR): 0.9118
#   F1 Score: 0.8732
# ---------------------------------------
#
# NAIVE BAYES (ALL FEATURES) MODEL
# Training set score: 0.8388
# Test set score: 0.8033
# Metrics:
#   Accuracy: 0.8033
#   Precision: 0.8235
#   Recall (TPR): 0.8235
#   F1 Score: 0.8235
# ---------------------------------------
#
#
# --- Using Features: ('Age', 'Sex', 'Rest_BP', 'ST_Depression', 'Max_HR_PostEx') ---
# KNN MODEL
# Training set score: 0.8058
# Test set score: 0.7705
# Metrics:
#   Accuracy: 0.7705
#   Precision: 0.8333
#   Recall (TPR): 0.7353
#   F1 Score: 0.7812
# ---------------------------------------
#
# NAIVE BAYES MODEL
# Training set score: 0.7686
# Test set score: 0.7541
# Metrics:
#   Accuracy: 0.7541
#   Precision: 0.7714
#   Recall (TPR): 0.7941
#   F1 Score: 0.7826
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Select features for clustering
selected_features = ["Age", "Cholesterol"]  # Two features for simplicity
X = data[selected_features]

# Perform hierarchical clustering and get cluster labels
clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')
cluster_labels = clustering.fit_predict(X)

# Add cluster labels to the data
data["Cluster"] = cluster_labels

# Scatterplot to visualize clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="Age",
    y="Cholesterol",
    hue="Cluster",
    data=data,
    palette="Set1",
    s=100
)
plt.title("Clusters Based on Age and Cholesterol")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.legend(title="Cluster")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# Define features that need normalization
features_to_normalize = ['Rest_BP', 'Cholesterol', 'Max_HR', 'ST_Depression', 'Vessel_Count']

# Normalize only the selected features
scaler = StandardScaler()
data[features_to_normalize] = scaler.fit_transform(data[features_to_normalize])

# %%
from sklearn.ensemble import RandomForestClassifier

# Define target and features
X = data.drop('Heart_Disease', axis=1)  # Drop target variable
y = data['Heart_Disease']              # Target variable

# Train a Random Forest Classifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X, y)

# Get feature importance
feature_importance = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
print(feature_importance)

# Plot feature importance
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
feature_importance.plot(kind='bar', color='skyblue')
plt.title('Feature Importance')
plt.ylabel('Importance Score')
plt.show()
# Out:
# Chest_Pain       0.118940
# Max_HR           0.112989
# Max_HR_PostEx    0.107208
# Vessel_Count     0.102611
# ST_Depression    0.100671
# Age              0.092361
# Cluster          0.077083
# Cholesterol      0.074353
# Rest_BP          0.072322
# Slope            0.049897
# Ex_Angina        0.036387
# Sex              0.025080
# Rest_ECG         0.019998
# Fasting_BS       0.010100
# dtype: float64

# %%
print(data.columns)
# Out:
# Index(['Age', 'Sex', 'Chest_Pain', 'Rest_BP', 'Cholesterol', 'Fasting_BS',
#        'Rest_ECG', 'Max_HR', 'Ex_Angina', 'ST_Depression', 'Slope',
#        'Vessel_Count', 'Max_HR_PostEx', 'Heart_Disease'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_curve, roc_auc_score, ConfusionMatrixDisplay
)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from itertools import combinations

# Define target and important features
target = 'Heart_Disease'
important_features = [
    'Chest_Pain', 'Max_HR', 'Max_HR_PostEx', 'Vessel_Count',
    'ST_Depression', 'Age', 'Cluster', 'Cholesterol',
    'Rest_BP', 'Slope'
]
features_to_normalize = ['Max_HR', 'Cholesterol', 'ST_Depression', 'Rest_BP']

# Normalize selected features
scaler = StandardScaler()
data[features_to_normalize] = scaler.fit_transform(data[features_to_normalize])

# Perform clustering and add the cluster labels
kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust number of clusters as needed
data['Cluster'] = kmeans.fit_predict(data[['Chest_Pain', 'Max_HR', 'ST_Depression', 'Age']])

# Split data
X = data[important_features]
y = data[target]

# Define feature subsets (e.g., top 3, top 5, top 7)
feature_subsets = [list(combo) for size in [3, 5, 7] for combo in combinations(important_features, size)]

# Function to evaluate models
def evaluate_model(model, X_train, y_train, X_test, y_test, model_name):
    print(f"--- {model_name.upper()} ---")
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"Training Score: {train_score:.4f}")
    print(f"Test Score: {test_score:.4f}")

    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, 'predict_proba') else None

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Precision: {precision:.4f}, F1 Score: {f1:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

    # ROC Curve
    if y_pred_proba is not None:
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        plt.figure()
        plt.plot(fpr, tpr, label=f"{model_name} (AUC = {roc_auc:.2f})", color="blue")
        plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve - {model_name}")
        plt.legend()
        plt.show()
    print("\n----------------------------------------\n")

# Iterate over subsets and evaluate models
for i, subset in enumerate(feature_subsets, 1):
    print(f"\n--- Feature Subset {i}: {subset} ---")

    # Split data based on the feature subset
    X_subset = X[subset]
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=0.2, random_state=42)

    # Define and evaluate models
    knn = KNeighborsClassifier(n_neighbors=5)
    nb = GaussianNB()

    # Evaluate KNN
    knn.fit(X_train, y_train)
    evaluate_model(knn, X_train, y_train, X_test, y_test, "KNN")

    # Evaluate Naive Bayes
    nb.fit(X_train, y_train)
    evaluate_model(nb, X_train, y_train, X_test, y_test, "Naive Bayes")

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, roc_auc_score

# Data for visualization (replace with actual metrics from your analysis)
top_model_results = {
    "Feature Subset 1 (KNN)": {"Accuracy": 0.8689, "Precision": 0.8750, "Recall": 0.8750, "F1 Score": 0.8750},
    "Feature Subset 1 (Naive Bayes)": {"Accuracy": 0.8852, "Precision": 0.9032, "Recall": 0.8750, "F1 Score": 0.8889},
    "Feature Subset 2 (KNN)": {"Accuracy": 0.8689, "Precision": 0.9000, "Recall": 0.8438, "F1 Score": 0.8710},
    "Feature Subset 2 (Naive Bayes)": {"Accuracy": 0.8852, "Precision": 0.8788, "Recall": 0.9062, "F1 Score": 0.8923},
}

# Bar plot for metrics comparison
metrics = ["Accuracy", "Precision", "Recall", "F1 Score"]
x = np.arange(len(metrics))  # Label locations
width = 0.2  # Bar width

fig, ax = plt.subplots(figsize=(10, 6))

for i, (model_name, results) in enumerate(top_model_results.items()):
    ax.bar(x + i * width, [results[m] for m in metrics], width, label=model_name)

ax.set_xlabel("Metrics")
ax.set_ylabel("Scores")
ax.set_title("Model Performance for Top Feature Subsets")
ax.set_xticks(x + width)
ax.set_xticklabels(metrics)
ax.legend()
plt.show()

# Confusion matrix for Naive Bayes (Subset 1) as an example
# Replace 'y_test' and 'y_pred' with actual data
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_nb)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - Naive Bayes (Subset 1)")
plt.show()

# ROC Curve for KNN and Naive Bayes (Subset 1)
y_pred_proba_knn = knn.predict_proba(X_test)[:, 1]
y_pred_proba_nb = nb.predict_proba(X_test)[:, 1]

fpr_knn, tpr_knn, _ = roc_curve(y_test, y_pred_proba_knn)
fpr_nb, tpr_nb, _ = roc_curve(y_test, y_pred_proba_nb)

plt.figure(figsize=(8, 6))
plt.plot(fpr_knn, tpr_knn, label="KNN (AUC = {:.2f})".format(roc_auc_score(y_test, y_pred_proba_knn)))
plt.plot(fpr_nb, tpr_nb, label="Naive Bayes (AUC = {:.2f})".format(roc_auc_score(y_test, y_pred_proba_nb)))
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Top-Performing Models")
plt.legend()
plt.grid()
plt.show()
